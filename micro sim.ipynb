# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Data file.csv')

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %% [markdown]
# we see that in that file we ahe the 209593 rows and 37 columns are present

# %% [markdown]
# in that file our main perpose is that the the label that the loan was failed or load was succefully in 5 dayes.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# in this data set we see that there are no null values are presents so we get all ready data for the project.

# %% [markdown]
# we see that in columns unnamed has no value this is only present that in row number so we drop that folder.

# %%
df=df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
df.tail()
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 209588   1089.19                1.0                0.0              4048  ...
# 209589   1728.36                4.0                0.0               773  ...
# 209590   8893.20                3.0                0.0              1539  ...
# 209591    984.58                2.0               38.0               773  ...
# 209592    631.20               13.0                0.0              7526  ...
#
# ...

# %%
df.sample(5)
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 139050      1  47409I95200   262.0   3194.518667      3221.060   2924.67
# 138724      1  49586I70784   281.0      6.452000         6.452    185.52
# 113759      0  73512I88688   998.0   1280.488333      1285.050    553.39
# 168301      0  02865I82732    64.0      0.000000         0.000   1289.34
# 53957       1  15960I96272  1758.0  13456.295000     13482.590   3367.41
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 139050   3343.83           3.000000                0.0              1539  ...
# 138724    185.52          38.000000                0.0               773  ...
# 113759   1146.86           3.000000                0.0               770  ...
# 168301   1289.34           0.000000                0.0                 0  ...
# 53957    3996.06      787959.004403                0.0              1539  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# # EDA process

# %%
sns.countplot('label',data=df)
print(df['label'].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# we see that there are around 183434 are credit succefully in 5 days and 26k are failed.

# %%
sns.countplot('last_rech_date_ma',data=df)
print(df['last_rech_date_ma'].value_counts())
# Out:
# 1.000000         47343
# 2.000000         26665
# 0.000000         20743
# 3.000000         19984
# 4.000000         15452
#                  ...
# 972385.270172        1
# 800187.053741        1
# 851900.041103        1
# 679670.490441        1
# 590843.121987        1
# Name: last_rech_date_ma, Length: 1186, dtype: int64

# %%
sns.countplot('maxamnt_loans30',data=df)
print(df['maxamnt_loans30'].value_counts())
# Out:
# 6.000000        179193
# 12.000000        26109
# 0.000000          3244
# 17083.998141         1
# 62511.750702         1
#                  ...
# 30346.385852         1
# 66821.819056         1
# 55716.817238         1
# 41580.156627         1
# 96927.243252         1
# Name: maxamnt_loans30, Length: 1050, dtype: int64

# %%
sns.countplot('medianamnt_loans30',data=df)
print(df['medianamnt_loans30'].value_counts())
# Out:
# 0.0    195445
# 1.0      7149
# 0.5      6538
# 2.0       420
# 1.5        38
# 3.0         3
# Name: medianamnt_loans30, dtype: int64

# %%
sns.countplot('pcircle',data=df)
print(df['pcircle'].value_counts())
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
sns.scatterplot('label','aon',data=df)
# Out:
# <AxesSubplot:xlabel='label', ylabel='aon'>

# %%
sns.scatterplot('last_rech_date_ma','last_rech_amt_ma',data=df)
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='last_rech_amt_ma'>

# %%
sns.scatterplot('maxamnt_loans30','amnt_loans30',data=df)
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='amnt_loans30'>

# %%
sns.countplot('maxamnt_loans90', data=df)
print(df['maxamnt_loans90'].value_counts())
# Out:
# 6     180945
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %%
sns.countplot('medianamnt_loans90', data=df)
print(df['medianamnt_loans90'].value_counts())
# Out:
# 0.0    197424
# 1.0      6172
# 0.5      5668
# 2.0       307
# 1.5        19
# 3.0         3
# Name: medianamnt_loans90, dtype: int64

# %%
sns.countplot('amnt_loans90', data=df)
print(df['amnt_loans90'].value_counts())
# Out:
# 6      69131
# 12     38908
# 18     23867
# 24     17216
# 30     12503
#        ...
# 438        1
# 360        1
# 372        1
# 402        1
# 426        1
# Name: amnt_loans90, Length: 69, dtype: int64

# %%
sns.countplot('cnt_loans90', data=df)
print(df['cnt_loans90'].value_counts())
# Out:
# 1.000000       73862
# 2.000000       37286
# 3.000000       23986
# 4.000000       16761
# 5.000000       12331
#                ...
# 3940.313295        1
# 2547.650840        1
# 2925.920310        1
# 1757.322504        1
# 2047.902454        1
# Name: cnt_loans90, Length: 1110, dtype: int64

# %%
sns.countplot('medianamnt_loans30', data=df)
print(df['medianamnt_loans30'].value_counts())
# Out:
# 0.0    195445
# 1.0      7149
# 0.5      6538
# 2.0       420
# 1.5        38
# 3.0         3
# Name: medianamnt_loans30, dtype: int64

# %%
sns.countplot('maxamnt_loans30', data=df)
print(df['maxamnt_loans30'].value_counts())
# Out:
# 6.000000        179193
# 12.000000        26109
# 0.000000          3244
# 17083.998141         1
# 62511.750702         1
#                  ...
# 30346.385852         1
# 66821.819056         1
# 55716.817238         1
# 41580.156627         1
# 96927.243252         1
# Name: maxamnt_loans30, Length: 1050, dtype: int64

# %%
sns.countplot('last_rech_date_da', data=df)
print(df['last_rech_date_da'].value_counts())
# Out:
# 0.000000         202861
# 7.000000            163
# 8.000000            160
# 11.000000           149
# 13.000000           148
#                   ...
# 731116.874493         1
# 609105.662326         1
# 945424.253703         1
# 505559.452693         1
# 636529.127252         1
# Name: last_rech_date_da, Length: 1174, dtype: int64

# %%
sns.countplot('label', data=df)
print(df['label'].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# # describe of data

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %% [raw]
# in that dataset wee see that the all columns mean values and standard deviation.
#
# all columns information is see in describtion minimun values of the each column
# 25th percentile of each column
# 50th percentile of each column
# 75th percentile of the each column
# as well as we see the maximum value of the each columns.
# we see the count of each columns are present in respresctive column

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(), cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # correlation

# %%
df.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# we see that the our target variable are the region and averageprice and see the correlation with that columns.
# the correlation is near to 1 is sign that there are very good correlation with each others.
# the correlation is near to 0 is sign that there are very bad correlation with each others.

# %%
df.corr()['label']
# Out:
# label                   1.000000
# aon                    -0.003785
# daily_decr30            0.168298
# daily_decr90            0.166150
# rental30                0.058085
# rental90                0.075521
# last_rech_date_ma       0.003728
# last_rech_date_da       0.001711
# last_rech_amt_ma        0.131804
# cnt_ma_rech30           0.237331
# fr_ma_rech30            0.001330
# sumamnt_ma_rech30       0.202828
# medianamnt_ma_rech30    0.141490
# medianmarechprebal30   -0.004829
# cnt_ma_rech90           0.236392
# fr_ma_rech90            0.084385
# sumamnt_ma_rech90       0.205793
# medianamnt_ma_rech90    0.120855
# medianmarechprebal90    0.039300
# cnt_da_rech30           0.003827
# fr_da_rech30           -0.000027
# cnt_da_rech90           0.002999
# fr_da_rech90           -0.005418
# cnt_loans30             0.196283
# amnt_loans30            0.197272
# maxamnt_loans30         0.000248
# medianamnt_loans30      0.044589
# cnt_loans90             0.004733
# ...

# %% [raw]
# +- 0.1 under that values we drop.

# %%
df=df.drop(['aon','rental30','last_rech_date_ma','last_rech_date_da','fr_ma_rech30','medianmarechprebal30','fr_da_rech30','cnt_da_rech90','maxamnt_loans30','cnt_loans90'],axis=1)

# %% [markdown]
# # skewness

# %%
df.skew()
# Out:
# label                   -2.270254
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental90                 4.437681
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# medianamnt_loans30       4.551043
# amnt_loans90             3.150006
# maxamnt_loans90          1.678304
# medianamnt_loans90       4.895720
# payback30                8.310695
# payback90                6.899951
# dtype: float64

# %% [raw]
# skewness between +-0.85 are good skewness.
# the skewness under 0.10 are not used for next process so we delete that columns.

# %%
df.head()
# Out:
#    label       msisdn  daily_decr30  daily_decr90  rental90  last_rech_amt_ma  \
# 0      0  21408I70789   3055.050000   3065.150000    260.13              1539
# 1      1  76462I70374  12122.000000  12124.750000   3691.26              5787
# 2      1  17943I70372   1398.000000   1398.000000    900.13              1539
# 3      1  55773I70781     21.228000     21.228000    159.42               947
# 4      1  03813I82730    150.619333    150.619333   1098.90              2309
#
#    cnt_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  cnt_ma_rech90  ...  \
# 0              2             3078.0                1539.0              2  ...
# 1              1             5787.0                5787.0              1  ...
# 2              1             1539.0                1539.0              1  ...
# 3              0                0.0                   0.0              1  ...
# 4              7            20029.0                2309.0              8  ...
#
# ...

# %%
df.shape
# Out:
# (209593, 26)

# %%
sns.distplot(df['daily_decr30'])
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Density'>

# %%
sns.distplot(df['daily_decr90'])
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='Density'>

# %%
sns.distplot(df['rental90'])
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Density'>

# %%
sns.distplot(df['last_rech_amt_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='Density'>

# %%
sns.distplot(df['cnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['payback90'])
# Out:
# <AxesSubplot:xlabel='payback90', ylabel='Density'>

# %%
df.plot(kind='box',subplots=True,layout=(5,5),figsize=(10,10))
# Out:
# label                      AxesSubplot(0.125,0.749828;0.133621x0.130172)
# daily_decr30            AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# daily_decr90             AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# rental90                AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# last_rech_amt_ma        AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# cnt_ma_rech30              AxesSubplot(0.125,0.593621;0.133621x0.130172)
# sumamnt_ma_rech30       AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# medianamnt_ma_rech30     AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# cnt_ma_rech90           AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# fr_ma_rech90            AxesSubplot(0.766379,0.593621;0.133621x0.130172)
# sumamnt_ma_rech90          AxesSubplot(0.125,0.437414;0.133621x0.130172)
# medianamnt_ma_rech90    AxesSubplot(0.285345,0.437414;0.133621x0.130172)
# medianmarechprebal90     AxesSubplot(0.44569,0.437414;0.133621x0.130172)
# ...

# %%
df.plot(kind='kde',subplots=True,layout=(5,5),figsize=(15,15))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1=df.select_dtypes(object)
df1
# Out:
#              msisdn pcircle       pdate
# 0       21408I70789     UPW  2016-07-20
# 1       76462I70374     UPW  2016-08-10
# 2       17943I70372     UPW  2016-08-19
# 3       55773I70781     UPW  2016-06-06
# 4       03813I82730     UPW  2016-06-22
# ...             ...     ...         ...
# 209588  22758I85348     UPW  2016-06-17
# 209589  95583I84455     UPW  2016-06-12
# 209590  28556I85350     UPW  2016-07-29
# 209591  59712I82733     UPW  2016-07-25
# 209592  65061I85339     UPW  2016-07-07
#
# [209593 rows x 3 columns]

# %%
for i in df1:
    le=LabelEncoder()
    df1[i]=le.fit_transform(df1[i])
df1
# Out:
#         msisdn  pcircle  pdate
# 0        40191        0     49
# 1       142291        0     70
# 2        33594        0     79
# 3       104157        0      5
# 4         6910        0     21
# ...        ...      ...    ...
# 209588   42866        0     16
# 209589  178248        0     11
# 209590   53995        0     58
# 209591  111388        0     54
# 209592  121263        0     36
#
# [209593 rows x 3 columns]

# %%
df2=df.select_dtypes(float)
df2
# Out:
#         daily_decr30  daily_decr90  rental90  sumamnt_ma_rech30  \
# 0        3055.050000   3065.150000    260.13             3078.0
# 1       12122.000000  12124.750000   3691.26             5787.0
# 2        1398.000000   1398.000000    900.13             1539.0
# 3          21.228000     21.228000    159.42                0.0
# 4         150.619333    150.619333   1098.90            20029.0
# ...              ...           ...       ...                ...
# 209588    151.872333    151.872333   1089.19            10404.0
# 209589     36.936000     36.936000   1728.36             3092.0
# 209590  11843.111667  11904.350000   8893.20             9334.0
# 209591  12488.228333  12574.370000    984.58            12154.0
# 209592   4489.362000   4534.820000    631.20             9065.0
#
#         medianamnt_ma_rech30  medianamnt_ma_rech90  medianmarechprebal90  \
# 0                     1539.0                1539.0                  7.50
# ...

# %%
df3=df.select_dtypes(int)
df3
# Out:
#         label  last_rech_amt_ma  cnt_ma_rech30  cnt_ma_rech90  fr_ma_rech90  \
# 0           0              1539              2              2            21
# 1           1              5787              1              1             0
# 2           1              1539              1              1             0
# 3           1               947              0              1             0
# 4           1              2309              7              8             2
# ...       ...               ...            ...            ...           ...
# 209588      1              4048              3              3             2
# 209589      1               773              4              6             2
# 209590      1              1539              5             11             5
# 209591      1               773              5              6             4
# 209592      1              7526              2              3            19
#
# ...

# %%
df=pd.concat([df1 , df2,df3], axis=1)

# %%
df
# Out:
#         msisdn  pcircle  pdate  daily_decr30  daily_decr90  rental90  \
# 0        40191        0     49   3055.050000   3065.150000    260.13
# 1       142291        0     70  12122.000000  12124.750000   3691.26
# 2        33594        0     79   1398.000000   1398.000000    900.13
# 3       104157        0      5     21.228000     21.228000    159.42
# 4         6910        0     21    150.619333    150.619333   1098.90
# ...        ...      ...    ...           ...           ...       ...
# 209588   42866        0     16    151.872333    151.872333   1089.19
# 209589  178248        0     11     36.936000     36.936000   1728.36
# 209590   53995        0     58  11843.111667  11904.350000   8893.20
# 209591  111388        0     54  12488.228333  12574.370000    984.58
# 209592  121263        0     36   4489.362000   4534.820000    631.20
#
#         sumamnt_ma_rech30  medianamnt_ma_rech30  medianamnt_ma_rech90  \
# ...

# %% [markdown]
# # removing the outliers

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64),
#  array([19, 14, 19, ..., 24, 11, 12], dtype=int64))

# %%
x=df.drop("label", axis=1)
y=df["label"]

# %% [markdown]
# transforming the data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.92855164,  0.        ,  0.57775419, ..., -0.09756296,
#         -0.25085016, -0.28561065],
#        [ 0.90402732,  0.        ,  1.36067787, ..., -0.09756296,
#         -0.25085016,  2.32582829],
#        [-1.07962307,  0.        ,  1.67272967, ..., -0.89478225,
#         -1.00571394, -0.28561065],
#        ...,
#        [-0.63401932,  0.        ,  0.92409065, ...,  1.45495146,
#          1.35845482,  2.32582829],
#        [ 0.41109115,  0.        ,  0.77241039, ...,  0.39323559,
#          0.50373963,  2.32582829],
#        [ 0.57252135,  0.        ,  0.03958262, ...,  0.39323559,
#          0.19226023,  2.32582829]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0     -0.291511
# 1      0.000000
# 2     -0.217699
# 3     -6.582717
# 4     -7.080193
# 5     -0.962717
# 6     -0.291322
# 7     -0.189628
# 8     -0.044604
# 9      7.506286
# 10     6.925820
# 11     3.447735
# 12     3.779598
# 13     0.298563
# 14     0.210887
# 15    -0.061262
# 16    -0.000145
# 17    -0.002465
# 18     0.142952
# 19    -0.192158
# 20    15.469700
# 21     0.036243
# 22     0.001948
# 23    -0.008988
# 24     0.364282
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.92855164,  0.        ,  0.57775419, ..., -0.09756296,
#         -0.25085016, -0.28561065],
#        [ 0.90402732,  0.        ,  1.36067787, ..., -0.09756296,
#         -0.25085016,  2.32582829],
#        [-1.07962307,  0.        ,  1.67272967, ..., -0.89478225,
#         -1.00571394, -0.28561065],
#        ...,
#        [-0.63401932,  0.        ,  0.92409065, ...,  1.45495146,
#          1.35845482,  2.32582829],
#        [ 0.41109115,  0.        ,  0.77241039, ...,  0.39323559,
#          0.50373963,  2.32582829],
#        [ 0.57252135,  0.        ,  0.03958262, ...,  0.39323559,
#          0.19226023,  2.32582829]])

# %% [markdown]
# # model building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
maxAccu=0
maxRS=0

for i in range(1,50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20, random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train, y_train)
    predrf=LR.predict(x_test)
    acc=accuracy_score(y_test, predrf)
    print('accuracy',acc,'random state',i)

if acc>maxAccu:
    maxAccu=acc
    maxRS=i
# Out:
# accuracy 0.884992485507765 random state 1
# accuracy 0.8819151220210406 random state 2
# accuracy 0.8830840430353778 random state 3
# accuracy 0.8839905532097617 random state 4
# accuracy 0.8818674109592309 random state 5
# accuracy 0.8837758534316181 random state 6
# accuracy 0.8790286027815549 random state 7
# accuracy 0.883346453875331 random state 8
# accuracy 0.8819628330828503 random state 9
# accuracy 0.884396097235144 random state 10
# accuracy 0.8836565757770939 random state 11
# accuracy 0.8791240249051743 random state 12
# accuracy 0.8850163410386698 random state 13
# accuracy 0.8847777857296214 random state 14
# accuracy 0.8843483861733343 random state 15
# accuracy 0.8862091175839119 random state 16
# accuracy 0.8849209189150504 random state 17
# accuracy 0.8849447744459553 random state 18
# accuracy 0.8847539301987166 random state 19
# accuracy 0.8804599346358454 random state 20
# accuracy 0.8840859753333811 random state 21
# accuracy 0.8834895870607601 random state 22
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=36)

# %%
x_train
# Out:
# array([[ 0.38409866,  0.        , -1.72018186, ..., -0.09756296,
#         -0.25085016, -0.28561065],
#        [ 1.26112949,  0.        ,  0.16852085, ..., -0.09756296,
#         -0.25085016, -0.28561065],
#        [ 0.62934585,  0.        ,  0.81065146, ...,  0.39323559,
#          0.50373963, -0.28561065],
#        ...,
#        [ 0.2802762 ,  0.        ,  0.69525518, ...,  1.91175524,
#          1.65138756,  2.32582829],
#        [-1.34632622,  0.        ,  0.65632989, ...,  1.62543101,
#          1.73183666, -0.28561065],
#        [ 1.37531183,  0.        , -0.13766608, ...,  0.39323559,
#          0.19226023, -0.28561065]])

# %%
y_train
# Out:
# 77459     1
# 134611    1
# 55407     1
# 189443    0
# 135486    0
#          ..
# 202377    1
# 27436     1
# 197594    1
# 138401    1
# 183208    1
# Name: label, Length: 167674, dtype: int64

# %%
x_test
# Out:
# array([[ 1.45105901,  0.        ,  1.6043967 , ..., -0.89478225,
#         -1.00571394, -0.28561065],
#        [ 1.30028526,  0.        , -0.51450835, ..., -0.89478225,
#         -1.00571394, -0.28561065],
#        [-0.19060253,  0.        ,  1.25389846, ...,  1.25904409,
#          1.56340832,  2.32582829],
#        ...,
#        [ 0.50917979,  0.        , -0.56415256, ..., -0.89478225,
#         -1.00571394, -0.28561065],
#        [ 0.67069208,  0.        ,  0.33573931, ...,  1.45495146,
#          1.35845482, -0.28561065],
#        [-1.79498364,  0.        , -0.46549401, ...,  0.39323559,
#          0.19226023, -0.28561065]])

# %%
y_test
# Out:
# 38639     1
# 198998    1
# 61083     1
# 51466     1
# 122745    1
#          ..
# 170997    1
# 125198    1
# 137350    1
# 37006     1
# 206938    1
# Name: label, Length: 41919, dtype: int64

# %% [markdown]
# given output are in binary or a categorical data

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(x_train, y_train)
predlr=LR.predict(x_test)
print('accuracy', accuracy_score(y_test, predlr)*100)
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# accuracy 88.6638517140199
# [[  705  4467]
#  [  285 36462]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.14      0.23      5172
#            1       0.89      0.99      0.94     36747
#
#     accuracy                           0.89     41919
#    macro avg       0.80      0.56      0.58     41919
# weighted avg       0.87      0.89      0.85     41919

# %% [markdown]
# the accuracy are around 88 % and it is a very good accuracy.

# %% [markdown]
# # Decision tree classifiers.

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
print('accuracy', accuracy_score(y_test, preddt)*100)
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# accuracy 88.275006560271
# [[ 2866  2306]
#  [ 2609 34138]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.55      0.54      5172
#            1       0.94      0.93      0.93     36747
#
#     accuracy                           0.88     41919
#    macro avg       0.73      0.74      0.74     41919
# weighted avg       0.89      0.88      0.88     41919

# %% [markdown]
# the accuracy are around 88 % and it is a very good accuracy.

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('accuracy', accuracy_score(y_test, predrf)*100)
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# accuracy 92.31851904864142
# [[ 2770  2402]
#  [  818 35929]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.54      0.63      5172
#            1       0.94      0.98      0.96     36747
#
#     accuracy                           0.92     41919
#    macro avg       0.85      0.76      0.79     41919
# weighted avg       0.92      0.92      0.92     41919

# %% [markdown]
# the accuracy are around 92 % and it is a very good accuracy.

# %% [markdown]
# # Support vector classifier

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(LR,x,y,cv=5)
print('cross validation score of logistic regression is', scr.mean())
# Out:
# cross validation score of logistic regression is 0.8835886702042351

# %%
scr2=cross_val_score(rf,x,y,cv=5)
print('cross validation score of random forest classifiers is', scr2.mean())
# Out:
# cross validation score of random forest classifiers is 0.9207511752360317

# %%
scr4=cross_val_score(dt,x,y,cv=5)
print('cross validation score of decision tree classifers is', scr4.mean())
# Out:
# cross validation score of decision tree classifers is 0.8832928669705545

# %% [markdown]
# we see that the logistic regression have the best accuracy score.

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(LR,x_test,y_test)
plt.title('roc auc curve')
plt.show()

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(rf,x_test,y_test)
plt.title('roc auc curve')
plt.show()

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(dt,x_test,y_test)
plt.title('roc auc curve')
plt.show()

# %%
import pickle
filename='micro sim.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(rf.predict(x_test))
df_com=pd.DataFrame({'original':a, 'predicted':predicted}, index=range(len(a)))
df_com
# Out:
#        original  predicted
# 0             1          1
# 1             1          1
# 2             1          1
# 3             1          1
# 4             1          1
# ...         ...        ...
# 41914         1          1
# 41915         1          1
# 41916         1          1
# 41917         1          1
# 41918         1          1
#
# [41919 rows x 2 columns]
