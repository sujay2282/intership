# %%
! pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome(r"D:\movies\chromedriver.exe")
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="19b3d3004acfbc439b85b0e11ea9f23e")>

# %%
driver.get('https://flight.yatra.com/air-search-ui/seodom/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=21%2F10%2F2022&hb=&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1659085713724&viewName=normal')

# %%
start_time=[]
end_time=[]
company_name=[]
start_point=[]
destination=[]
price=[]
time_taken=[]
stops=[]

# %%
company=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
company
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="ad4ea2b9-1457-4f61-9b88-2e071d12a72b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="9b5fb9b4-3820-4e4f-aead-b00ee90fb408")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="5c25f572-82b4-4eaa-a341-39cc8f5e0028")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="e3d9f35d-d98c-49d6-8b1a-29b094c1d81c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="1949d130-e7df-49ed-b4a4-ae7187764206")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="89cc990d-9210-4d58-9994-637d98f81605")>,
# ...

# %%
for i in company:
    tit=i.text
    company_name.append(tit)
    
company_name
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
len(company_name)
# Out:
# 1440

# %%
start=driver.find_elements_by_xpath("//div[@class='i-b pr']")
start
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="2be01287-7e8d-4861-97ba-99f5fd688883")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="8e03575a-e930-49fb-b06a-6c8e96de9021")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="4cef9592-47b8-4559-a245-593037c14830")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="726896c3-f7d8-49d7-af2f-0d256b101f3f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="831f9fd6-b42e-4c23-93ab-fe36d030abe0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="e05ff22d-b1a9-49c3-bbd5-7380bfd7092e")>,
# ...

# %%
for i in start:
    tit=i.text
    start_time.append(tit)
    
start_time
# Out:
# ['06:50',
#  '08:00',
#  '14:30',
#  '02:40',
#  '10:55',
#  '15:45',
#  '18:20',
#  '19:45',
#  '22:45',
#  '20:50',
#  '07:00',
#  '08:00',
#  '22:30',
#  '09:00',
#  '14:00',
#  '21:15',
#  '10:00',
#  '13:00',
#  '07:20',
#  '19:00',
#  '07:20',
#  '19:45',
#  '21:40',
#  '02:10',
#  '11:55',
#  '06:30',
#  '07:20',
#  '10:45',
#  '17:00',
#  '23:35',
#  '05:30',
#  '14:10',
#  '15:10',
#  '16:15',
#  '19:45',
#  '08:45',
#  '18:10',
#  '08:00',
#  '09:35',
#  '21:45',
#  '05:55',
#  '21:55',
#  '09:30',
#  '14:20',
#  '15:30',
#  '16:55',
#  '07:30',
#  '10:20',
#  '12:45',
#  '19:00',
#  '08:50',
#  '11:40',
#  '17:45',
#  '08:00',
#  '21:40',
#  '21:00',
#  '20:00',
#  '17:55',
#  '19:00',
#  '19:45',
#  '20:40',
#  '09:35',
#  '14:30',
#  '18:10',
#  '21:20',
#  '18:10',
#  '21:20',
#  '18:10',
#  '06:30',
#  '06:30',
#  '21:20',
#  '16:40',
#  '18:45',
#  '06:00',
#  '14:45',
#  '05:05',
#  '18:45',
#  '11:10',
#  '08:25',
#  '05:15',
#  '13:20',
#  '12:50',
#  '20:00',
# ...

# %%
end=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
end
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="e62814d4-b63b-4108-b24c-a01276ef5404")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="7f2c2852-d42c-477f-8fa2-31fb4753a0db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="f36ad583-4fc3-4f6d-8193-aaa260dda540")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="80c154d4-b6b5-403e-8d60-03e504829def")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="9e3985ba-0470-48a1-8af6-b04ca51a957c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="2672a75d-3465-4c9f-b9be-3d476462cfb5")>,
# ...

# %%
for i in end:
    tit=i.text
    end_time.append(tit)
    
end_time
# Out:
# ['08:55',
#  '10:10',
#  '16:40',
#  '04:55',
#  '13:10',
#  '18:00',
#  '20:35',
#  '22:00',
#  '01:00\n+ 1 day',
#  '23:20',
#  '09:05',
#  '10:10',
#  '00:40\n+ 1 day',
#  '11:15',
#  '16:15',
#  '23:35',
#  '12:35',
#  '18:20',
#  '18:20',
#  '21:10',
#  '09:35',
#  '22:00',
#  '23:55',
#  '04:10',
#  '13:55',
#  '08:35',
#  '09:25',
#  '12:50',
#  '19:05',
#  '01:40\n+ 1 day',
#  '07:40',
#  '16:20',
#  '17:20',
#  '18:25',
#  '21:55',
#  '11:00',
#  '20:25',
#  '10:20',
#  '12:00',
#  '00:10\n+ 1 day',
#  '07:55',
#  '23:55',
#  '11:35',
#  '16:30',
#  '17:40',
#  '19:05',
#  '09:45',
#  '12:35',
#  '15:00',
#  '21:15',
#  '11:10',
#  '14:00',
#  '20:05',
#  '14:05',
#  '07:15\n+ 1 day',
#  '07:15\n+ 1 day',
#  '22:10',
#  '20:10',
#  '21:15',
#  '21:55',
#  '22:50',
#  '20:40',
#  '18:10',
#  '23:15',
#  '06:15\n+ 1 day',
#  '06:15\n+ 1 day',
#  '09:40\n+ 1 day',
#  '09:40\n+ 1 day',
#  '23:15',
#  '06:15\n+ 1 day',
#  '23:15\n+ 1 day',
#  '21:20',
#  '00:05\n+ 1 day',
# ...

# %%
startpoint=driver.find_elements_by_xpath("//p[1][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
startpoint
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="d362cf4a-9f7f-44e6-87f0-80866a821966")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="1e3254c2-1652-4efc-aeee-5d09ecfb6c30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="571b95f7-ea88-4b9f-ac59-2c6dea3198f2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="6f0060e7-f88a-4b56-a09a-f8a645ae1d5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="bb13f607-8d61-47f5-84e4-de25144b3ea4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="afe04861-e3ff-47bb-a4fd-c862afe3773b")>,
# ...

# %%
for i in startpoint:
    tit=i.text
    start_point.append(tit)
    
start_point
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
time=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="eaf52d58-2412-4093-a1b3-e6053034e19c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="ed44cd5b-1e6a-46f8-b9fe-41d947d75b79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="a3f2fbd7-34fe-4b60-933f-e74b152183ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="1c89ffa7-3e6e-4ed0-a076-b1f1a57740aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="0fe5b536-2668-4b65-8df5-b3cd1390842f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="e970ed4a-d178-40ee-807c-134965034fb4")>,
# ...

# %%
for i in time:
    tit=i.text
    time_taken.append(tit)
    
time_taken
# Out:
# ['2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 30m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 35m',
#  '5h 20m',
#  '11h 00m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 00m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 25m',
#  '2h 25m',
#  '2h 00m',
#  '2h 00m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '6h 05m',
#  '9h 35m',
#  '10h 15m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '11h 05m',
#  '3h 40m',
#  '5h 05m',
#  '8h 55m',
#  '12h 05m',
#  '12h 20m',
#  '15h 30m',
#  '16h 45m',
#  '23h 45m',
#  '25h 55m',
#  '4h 40m',
#  '5h 20m',
#  '6h 50m',
#  '9h 20m',
#  '8h 15m',
# ...

# %%
fare=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
fare
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="d678127b-5e94-414c-a842-085377bbf6b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="94d6be2a-d82d-4daf-935b-89100655600f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="b89d8c92-d31c-4fb1-80c0-928bb929f802")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="40497e83-a51b-4b5c-af43-fe96bd92f547")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="782abd5d-6843-4909-b25c-61988f4be812")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="490028e5-4732-4c63-bbba-1dbcfd37ec84")>,
# ...

# %%
for i in fare:
    tit=i.text
    price.append(tit)
    
price
# Out:
# ['5,698',
#  '5,698',
#  '5,698',
#  '5,698',
#  '5,698',
#  '5,698',
#  '5,698',
#  '5,698',
#  '5,698',
#  '5,698',
#  '5,877',
#  '5,877',
#  '5,877',
#  '5,877',
#  '5,877',
#  '5,877',
#  '5,877',
#  '5,935',
#  '5,935',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,981',
#  '5,981',
#  '5,981',
#  '6,107',
#  '6,107',
#  '6,107',
#  '6,218',
#  '6,218',
#  '6,355',
#  '6,395',
#  '6,827',
#  '6,827',
#  '6,827',
#  '6,827',
#  '6,827',
#  '6,827',
#  '6,827',
#  '6,827',
#  '7,427',
#  '7,477',
#  '7,477',
#  '7,477',
#  '7,576',
#  '7,826',
#  '8,150',
#  '8,201',
#  '8,201',
#  '8,284',
#  '8,480',
#  '8,480',
# ...

# %%
stoppoint=driver.find_elements_by_xpath("//p[2][@class='fs-10 font-lightgrey no-wrap city ellipsis']")
stoppoint
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="ad85c9a4-da27-4534-b68d-8be49e760811")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="1b9d35c1-93a1-47ba-8478-67eb887c637b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="992db67a-02fc-4408-abe6-c8bf621b2d09")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="d010c5e1-a0b5-48fa-a4b4-2ee4ba99fd9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="ffa459b3-710c-4901-8e97-3b4f38439a9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="19b3d3004acfbc439b85b0e11ea9f23e", element="17e2d71b-45f1-409d-b562-8a1d911e6dcb")>,
# ...

# %%
for i in stoppoint:
    tit=i.text
    destination.append(tit)
    
destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
len(destination)
# Out:
# 1440

# %%
change=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[2]/div/input')
change.click()

# %%
search=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[2]/div/input')
search.send_keys('bengalore')

# %%
search1=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/div[1]/div/button')
search1.click()

# %%
change=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[3]/div/input')
change.click()

# %%
search=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[3]/div/input')
search.send_keys('chennai')

# %%
search1=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/div[1]/div/button')
search1.click()

# %%
change=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[2]/div/input')
change.click()

# %%
search=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[2]/div/input')
search.send_keys('hydrabad')

# %%
change=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[3]/div/input')
change.click()

# %%
search=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/ul[2]/li[3]/div/input')
search.send_keys('kolkata')

# %%
search1=driver.find_element_by_xpath('/html/body/section[1]/section/div/div/form/div[1]/div/button')
search1.click()

# %%
print(len(company_name))
print(len(start_time))
print(len(end_time))
print(len(start_point))
print(len(destination))
print(len(time_taken))
print(len(price))
# Out:
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440
# 1440

# %% [markdown]
# creating the dataframe

# %%
df=pd.DataFrame({'company_name': company_name , 'start_time': start_time , 'end_time': end_time , 'starting_point':start_point ,'destination':destination ,'time_taken':time_taken ,'price':price })
df
# Out:
#      company_name start_time end_time starting_point destination time_taken  \
# 0        Go First      06:50    08:55      New Delhi      Mumbai     2h 05m
# 1        Go First      08:00    10:10      New Delhi      Mumbai     2h 10m
# 2        Go First      14:30    16:40      New Delhi      Mumbai     2h 10m
# 3        Go First      02:40    04:55      New Delhi      Mumbai     2h 15m
# 4        Go First      10:55    13:10      New Delhi      Mumbai     2h 15m
# ...           ...        ...      ...            ...         ...        ...
# 1435      Vistara      09:45    19:50      Bangalore     Chennai    10h 05m
# 1436      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1437      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1438      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1439    Air India      06:10    12:40      Bangalore     Chennai     6h 30m
#
#        price
# 0      5,698
# 1      5,698
# ...

# %% [markdown]
# EDA process

# %%
df.shape
# Out:
# (1440, 7)

# %% [markdown]
# in this dataframe there are 1440 rows and 7 columns are presents.

# %%
df.head()
# Out:
#   company_name start_time end_time starting_point destination time_taken  \
# 0     Go First      06:50    08:55      New Delhi      Mumbai     2h 05m
# 1     Go First      08:00    10:10      New Delhi      Mumbai     2h 10m
# 2     Go First      14:30    16:40      New Delhi      Mumbai     2h 10m
# 3     Go First      02:40    04:55      New Delhi      Mumbai     2h 15m
# 4     Go First      10:55    13:10      New Delhi      Mumbai     2h 15m
#
#    price
# 0  5,698
# 1  5,698
# 2  5,698
# 3  5,698
# 4  5,698

# %%
df.tail()
# Out:
#      company_name start_time end_time starting_point destination time_taken  \
# 1435      Vistara      09:45    19:50      Bangalore     Chennai    10h 05m
# 1436      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1437      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1438      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1439    Air India      06:10    12:40      Bangalore     Chennai     6h 30m
#
#        price
# 1435  19,295
# 1436  19,295
# 1437  19,295
# 1438  19,295
# 1439  21,871

# %%
df.sample(5)
# Out:
#      company_name start_time        end_time starting_point destination  \
# 744     Air India      21:20  10:10\n+ 1 day      Bangalore      Mumbai
# 829       Vistara      21:40           23:25      Bangalore      Mumbai
# 33         IndiGo      16:15           18:25      New Delhi      Mumbai
# 1421      Vistara      20:10  23:05\n+ 1 day      Bangalore     Chennai
# 985      Go First      15:45           20:05      Bangalore      Mumbai
#
#      time_taken   price
# 744     12h 50m  10,437
# 829      1h 45m   5,847
# 33       2h 10m   5,954
# 1421    26h 55m  12,441
# 985      4h 20m   7,766

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   company_name    1440 non-null   object
#  1   start_time      1440 non-null   object
#  2   end_time        1440 non-null   object
#  3   starting_point  1440 non-null   object
#  4   destination     1440 non-null   object
#  5   time_taken      1440 non-null   object
#  6   price           1440 non-null   object
# dtypes: object(7)
# memory usage: 78.9+ KB

# %%
df.isnull().sum()
# Out:
# company_name      0
# start_time        0
# end_time          0
# starting_point    0
# destination       0
# time_taken        0
# price             0
# dtype: int64

# %% [markdown]
# we see that in that dataframe there are no null values are present so we further look next.

# %% [markdown]
# in that dataset the price are the output value of the set so we see that also.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # visualization of the data

# %%
sns.countplot('company_name', data=df)
print(df['company_name'].value_counts())
# Out:
# Vistara      497
# IndiGo       370
# Air India    273
# Go First     156
# Air Asia      74
# SpiceJet      70
# Name: company_name, dtype: int64

# %%
sns.countplot('start_time', data=df)
print(df['start_time'].value_counts())
# Out:
# 07:45    100
# 07:00     50
# 11:30     50
# 20:10     40
# 21:20     37
#         ...
# 15:20      3
# 08:25      3
# 05:05      3
# 16:40      3
# 20:55      3
# Name: start_time, Length: 138, dtype: int64

# %%
sns.countplot('end_time', data=df)
print(df['end_time'].value_counts())
# Out:
# 21:15             34
# 23:05             32
# 11:50\n+ 1 day    32
# 00:40\n+ 1 day    31
# 08:50\n+ 1 day    28
#                   ..
# 13:20              3
# 23:15\n+ 1 day     3
# 18:10              3
# 14:05              3
# 13:35\n+ 1 day     3
# Name: end_time, Length: 170, dtype: int64

# %%
sns.countplot('starting_point', data=df)
print(df['starting_point'].value_counts())
# Out:
# Bangalore    936
# New Delhi    504
# Name: starting_point, dtype: int64

# %%
sns.countplot('destination', data=df)
print(df['destination'].value_counts())
# Out:
# Mumbai     1104
# Chennai     336
# Name: destination, dtype: int64

# %%
sns.countplot('time_taken', data=df)
print(df['time_taken'].value_counts())
# Out:
# 2h 15m     61
# 2h 10m     48
# 1h 35m     32
# 1h 55m     24
# 2h 05m     24
#            ..
# 25h 55m     3
# 23h 45m     3
# 16h 45m     3
# 15h 30m     3
# 2h 35m      3
# Name: time_taken, Length: 173, dtype: int64

# %%
sns.countplot('price', data=df)
print(df['price'].value_counts())
# Out:
# 13,520    88
# 10,080    56
# 5,954     51
# 10,437    44
# 8,577     44
#           ..
# 16,539     3
# 15,909     3
# 8,939      3
# 13,724     3
# 10,457     3
# Name: price, Length: 148, dtype: int64

# %%
sns.scatterplot('time_taken','price',data=df)
# Out:
# <AxesSubplot:xlabel='time_taken', ylabel='price'>

# %%
sns.scatterplot('destination','price',data=df)
# Out:
# <AxesSubplot:xlabel='destination', ylabel='price'>

# %%
sns.scatterplot('starting_point','price',data=df)
# Out:
# <AxesSubplot:xlabel='starting_point', ylabel='price'>

# %%
sns.scatterplot('end_time','price',data=df)
# Out:
# <AxesSubplot:xlabel='end_time', ylabel='price'>

# %%
sns.scatterplot('start_time','price',data=df)
# Out:
# <AxesSubplot:xlabel='start_time', ylabel='price'>

# %%
sns.scatterplot('company_name','price',data=df)
# Out:
# <AxesSubplot:xlabel='company_name', ylabel='price'>

# %% [markdown]
# in that columns the data sre in the string form so we convert them in int form.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1=df.select_dtypes(object)

# %%
df1
# Out:
#      company_name start_time end_time starting_point destination time_taken  \
# 0        Go First      06:50    08:55      New Delhi      Mumbai     2h 05m
# 1        Go First      08:00    10:10      New Delhi      Mumbai     2h 10m
# 2        Go First      14:30    16:40      New Delhi      Mumbai     2h 10m
# 3        Go First      02:40    04:55      New Delhi      Mumbai     2h 15m
# 4        Go First      10:55    13:10      New Delhi      Mumbai     2h 15m
# ...           ...        ...      ...            ...         ...        ...
# 1435      Vistara      09:45    19:50      Bangalore     Chennai    10h 05m
# 1436      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1437      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1438      Vistara      11:30    23:05      Bangalore     Chennai    11h 35m
# 1439    Air India      06:10    12:40      Bangalore     Chennai     6h 30m
#
#        price
# 0      5,698
# 1      5,698
# ...

# %%
for i in df1:
    le=LabelEncoder()
    df1[i]=le.fit_transform(df1[i])

# %%
df=df1

# %%
df
# Out:
#       company_name  start_time  end_time  starting_point  destination  \
# 0                2          19        38               1            1
# 1                2          28        49               1            1
# 2                2          74       107               1            1
# 3                2           2        11               1            1
# 4                2          51        76               1            1
# ...            ...         ...       ...             ...          ...
# 1435             5          41       131               0            0
# 1436             5          56       158               0            0
# 1437             5          56       158               0            0
# 1438             5          56       158               0            0
# 1439             1          14        74               0            0
#
#       time_taken  price
# 0             99     90
# 1            100     90
# 2            100     90
# 3            101     90
# ...

# %% [markdown]
# we see the describation of the data

# %%
df.describe()
# Out:
#        company_name   start_time     end_time  starting_point  destination  \
# count   1440.000000  1440.000000  1440.000000     1440.000000  1440.000000
# mean       3.097222    62.988889    94.970139        0.350000     0.766667
# std        1.658551    38.890411    50.659800        0.477135     0.423100
# min        0.000000     0.000000     0.000000        0.000000     0.000000
# 25%        2.000000    26.000000    50.000000        0.000000     1.000000
# 50%        3.000000    56.000000   105.000000        0.000000     1.000000
# 75%        5.000000   100.000000   140.000000        1.000000     1.000000
# max        5.000000   137.000000   169.000000        1.000000     1.000000
#
#        time_taken        price
# count  1440.00000  1440.000000
# mean     90.98125    70.349306
# std      48.87502    42.235247
# min       0.00000     0.000000
# 25%      53.00000    38.000000
# 50%      99.00000    74.000000
# 75%     132.00000   101.250000
# max     172.00000   147.000000

# %% [raw]
# in that dataset wee see that the all columns mean values and standard deviation.
#
# all columns information is see in describtion minimun values of the each column
# 25th percentile of each column
# 50th percentile of each column
# 75th percentile of the each column
# as well as we see the maximum value of the each columns.
# we see the count of each columns are present in respresctive column

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.describe(), cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # correlation

# %%
df.corr()
# Out:
#                 company_name  start_time  end_time  starting_point  \
# company_name        1.000000   -0.055059  0.114469       -0.064105
# start_time         -0.055059    1.000000 -0.043804        0.046948
# end_time            0.114469   -0.043804  1.000000       -0.055543
# starting_point     -0.064105    0.046948 -0.055543        1.000000
# destination        -0.134021   -0.021443 -0.036119        0.404820
# time_taken         -0.026562   -0.092023 -0.069950        0.150025
# price              -0.106952   -0.008214 -0.075169        0.159558
#
#                 destination  time_taken     price
# company_name      -0.134021   -0.026562 -0.106952
# start_time        -0.021443   -0.092023 -0.008214
# end_time          -0.036119   -0.069950 -0.075169
# starting_point     0.404820    0.150025  0.159558
# destination        1.000000    0.156659  0.276940
# time_taken         0.156659    1.000000  0.173442
# price              0.276940    0.173442  1.000000

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(), cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# we see that the our target variable are the region and averageprice and see the correlation with that columns.
# the correlation is near to 1 is sign that there are very good correlation with each others.
# the correlation is near to 0 is sign that there are very bad correlation with each others.

# %%
df.corr()['price']
# Out:
# company_name     -0.106952
# start_time       -0.008214
# end_time         -0.075169
# starting_point    0.159558
# destination       0.276940
# time_taken        0.173442
# price             1.000000
# Name: price, dtype: float64

# %% [markdown]
# # skewness

# %%
df.skew()
# Out:
# company_name     -0.220842
# start_time        0.290138
# end_time         -0.291101
# starting_point    0.629627
# destination      -1.262292
# time_taken       -0.231160
# price            -0.076405
# dtype: float64

# %%
plt.hist('price',data=df, bins=10)
# Out:
# (array([223.,  78.,  96., 245.,  69., 116., 259., 113., 149.,  92.]),
#  array([  0. ,  14.7,  29.4,  44.1,  58.8,  73.5,  88.2, 102.9, 117.6,
#         132.3, 147. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist('start_time',data=df, bins=10)
# Out:
# (array([ 78., 298., 204., 118., 146., 101.,  97., 130., 149., 119.]),
#  array([  0. ,  13.7,  27.4,  41.1,  54.8,  68.5,  82.2,  95.9, 109.6,
#         123.3, 137. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist('end_time',data=df, bins=10)
# Out:
# (array([119., 100., 143.,  96., 120., 117., 165., 192., 169., 219.]),
#  array([  0. ,  16.9,  33.8,  50.7,  67.6,  84.5, 101.4, 118.3, 135.2,
#         152.1, 169. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# we find the outliers

# %%
df.columns
# Out:
# Index(['company_name', 'start_time', 'end_time', 'starting_point',
#        'destination', 'time_taken', 'price'],
#       dtype='object')

# %%
df['company_name'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['start_time'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['end_time'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['starting_point'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['destination'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['time_taken'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['price'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see that there no such outliers are presents.

# %% [markdown]
# outlier removing using zscore method

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# we see that there are no outliers are presents.

# %% [markdown]
# seprating the dataset

# %%
x=df.drop("price", axis=1)
y=df["price"]

# %%
from sklearn.preprocessing import power_transform
x_train=power_transform(x,method='yeo-johnson')

# %%
x_train
# Out:
# array([[-0.66162707, -1.19807649, -1.10524926,  1.36277029,  0.55167728,
#          0.2030889 ],
#        [-0.66162707, -0.84179717, -0.87386995,  1.36277029,  0.55167728,
#          0.22262605],
#        [-0.66162707,  0.42485583,  0.26787943,  1.36277029,  0.55167728,
#          0.22262605],
#        ...,
#        [ 1.14754377, -0.00292514,  1.208164  , -0.73379939, -1.81265393,
#         -1.54948224],
#        [ 1.14754377, -0.00292514,  1.208164  , -0.73379939, -1.81265393,
#         -1.54948224],
#        [-1.26496437, -1.43287747, -0.36879737, -0.73379939, -1.81265393,
#          0.90999489]])

# %%
y
# Out:
# 0       90
# 1       90
# 2       90
# 3       90
# 4       90
#         ..
# 1435    74
# 1436    74
# 1437    74
# 1438    74
# 1439    76
# Name: price, Length: 1440, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.66178453, -1.13149153, -1.12495371,  1.36277029,  0.55167728,
#          0.16412343],
#        [-0.66178453, -0.89999162, -0.90774359,  1.36277029,  0.55167728,
#          0.18459089],
#        [-0.66178453,  0.28323013,  0.23754615,  1.36277029,  0.55167728,
#          0.18459089],
#        ...,
#        [ 1.14765166, -0.17976968,  1.24461126, -0.73379939, -1.81265393,
#         -1.51420811],
#        [ 1.14765166, -0.17976968,  1.24461126, -0.73379939, -1.81265393,
#         -1.51420811],
#        [-1.26492993, -1.26010259, -0.41408422, -0.73379939, -1.81265393,
#          0.92141937]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
# only for the selection the random value
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train , y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"at random state {i}, the traing accuracy is- {r2_score(y_train,pred_train)}")
    print(f"at random state {i}, the testing accuracy is-{r2_score(y_test,pred_test)}")
    print('\n')
# Out:
# at random state 0, the traing accuracy is- 0.09773825116063883
# at random state 0, the testing accuracy is-0.12026656822136816
#
#
# at random state 1, the traing accuracy is- 0.09683758999667758
# at random state 1, the testing accuracy is-0.11756835446003322
#
#
# at random state 2, the traing accuracy is- 0.12109738897506539
# at random state 2, the testing accuracy is-0.02113080702975001
#
#
# at random state 3, the traing accuracy is- 0.10608293551926606
# at random state 3, the testing accuracy is-0.07841988438536684
#
#
# at random state 4, the traing accuracy is- 0.10716881855634441
# at random state 4, the testing accuracy is-0.08141920100729083
#
#
# at random state 5, the traing accuracy is- 0.09469037750525133
# at random state 5, the testing accuracy is-0.13079077273118844
#
#
# at random state 6, the traing accuracy is- 0.09534379772231572
# at random state 6, the testing accuracy is-0.1193936175681487
#
#
# ...

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30, random_state=15)

# %%
x_train.shape
# Out:
# (1008, 6)

# %%
y_train.shape
# Out:
# (1008,)

# %%
x_test.shape
# Out:
# (432, 6)

# %%
lr=LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-3.41781946,  0.09467142, -0.75540337,  0.94850002, 10.46263409,
#         5.835837  ])

# %%
lr.intercept_
# Out:
# 70.75501349803739

# %%
lr.score(x_train, y_train)
# Out:
# 0.10829422247231146

# %%
pred=lr.predict(x_test)
print('/n predicted result prise',pred_test)
print('actual price',y_test)
# Out:
# /n predicted result prise [86.5186952  63.88623228 47.09737475 45.52446093 92.08118029 76.2655769
#  73.71399572 80.72101724 72.74283497 76.73323407 82.94020443 80.30207262
#  76.59300983 74.22019647 50.24907612 71.72083101 51.41815763 77.42052859
#  79.88483305 74.4601756  45.46859173 81.71832801 83.94025528 78.4549752
#  84.11774612 75.72207442 43.29973398 55.8557529  77.5350027  58.72482447
#  74.67639859 81.94736705 79.51340415 80.16639927 44.60013165 83.02952086
#  79.08074463 76.59300983 81.31653003 69.29189264 71.69047626 69.63908815
#  78.93153307 78.45971949 75.24865083 62.00955658 50.39962118 73.71399572
#  68.24171587 84.54866385 40.15589008 81.47192598 74.17742559 73.5276012
#  43.48228163 79.50467718 82.38009352 51.23964808 73.6141553  73.03196318
#  71.60363288 78.46638928 81.42746973 88.87531585 56.75177926 56.98110282
#  66.77153185 71.86378986 74.89406848 74.4601756  87.49189681 84.54866385
#  56.75177926 39.94913575 81.29117586 80.72101724 72.67260263 76.95139115
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001, .001, .01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train, y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss=r2_score(y_test, pred_ls)
lss
# Out:
# 0.08075035943059894

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.08143151014307488

# %% [markdown]
# esemble tecq

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'], 'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clt=GridSearchCV(rf,parameters)
clt.fit(x_train,y_train)

print(clt.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='log2')
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_decision=rf.predict(x_test)

rfs=r2_score(y_test,pred_decision)
print('R2 score', rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('Cross Val Score', rfc*100)
# Out:
# R2 score 92.63253924735281
# Cross Val Score 87.29092666103678

# %% [markdown]
# getting model saving

# %%
import pickle
filename='intership_airplane_price.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %%
loaded_model=pickle.load(open('intership_airplane_price.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.9263253924735281

# %% [markdown]
# # conclusion

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(rf.predict(x_test))
df_com=pd.DataFrame({'original':a, 'predicted':predicted}, index=range(len(a)))
df_com
# Out:
#      original  predicted
# 0         141     137.59
# 1          79      78.80
# 2         125     123.76
# 3           5      23.68
# 4         130     110.95
# ..        ...        ...
# 427        10      11.83
# 428        32      31.64
# 429        52      54.07
# 430         9      16.86
# 431        99      96.16
#
# [432 rows x 2 columns]

# %% [markdown]
# we see the original value and our model predicted values are see in that conclusion.

# %%
so in that dataset we see that the predicted data as well as the original data are almost same.
